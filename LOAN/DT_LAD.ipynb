# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

# %%
df = pd.read_csv('loan_approval_dataset.csv')
X = df.drop(columns=['Loan_Approved'])
y= df['Loan_Approved']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
model_1 = DecisionTreeClassifier() #based on pure node it will recognize leaf node
model_2 = DecisionTreeClassifier() #with the help of min_samples_split and min_samples_leaf it will recognize the leaf node

# %%
'''dataset for DecisionTreeClassifier(), DecisionTreeClassifier() train and evaluate the model
    write conclusion and metrics'''
# Out:
# 'dataset for DecisionTreeClassifier(), DecisionTreeClassifier() train and evaluate the model\n    write conclusion and metrics'
