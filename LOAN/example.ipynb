# %%
from sklearn.linear_model import LogisticRegression

# %%
'''
1. penalty
# penalty: Literal['l1', 'l2', 'elasticnet'] | None = "l2"
model=LogisticRegression(penalty='l1')
model=LogisticRegression(penalty='l2')
model=LogisticRegression(penalty='elasticnet')

2. solver
It is an optimization engine which helps gradient descent to optimize the weights
# solver: Literal['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'] = "lbfgs"

multiclass support:

solver	            l1_ratio           	multinomial multiclass
'lbfgs'	          l1_ratio=0	              yes
'liblinear'  	l1_ratio=1 or l1_ratio=0	  no
'newton-cg'     	l1_ratio=0	              yes
'newton-cholesky'	l1_ratio=0                yes
'sag'	           l1_ratio=0	              yes
'saga'      	0<=l1_ratio<=1	              yes

3. max_iter
It accepts only integer
When more features,it restricts the iterations(with the help of tolerance-it helps gradient descent to stop iterations)
Use default tolerance, don't change it
max_iter: Int = 100

4. class_weight
class_weight: Mapping | str | None = None
class_weight = None | 'balanced'
When the dataset is inbalanced we use 'balanced'
Inbalanced dataset?(how to check)
By looking at target column(value_counts())
if the unique value count is almost equal => balanced Eg.: spam->450 | notspam->550
inbalanced=> spam->700 | notspam->300
how to handle inbalnced dataset?
1. class_weight = 'balanced'
2. Re-sampling

5. C
C: Float = 1
'''
model=LogisticRegression(penalty='l1')
