# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('student_performance.csv')

# %%
# Map categorical grades to numeric values for modeling
grade_map = {'A': 4, 'B': 3, 'C': 2, 'D': 1}
df['grade_numeric'] = df['grade'].map(grade_map)
df['grade_numeric'].head()
# Out:
# 0    4.0
# 1    3.0
# 2    4.0
# 3    4.0
# 4    4.0
# Name: grade_numeric, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   student_id               1000000 non-null  int64
#  1   weekly_self_study_hours  1000000 non-null  float64
#  2   attendance_percentage    1000000 non-null  float64
#  3   class_participation      1000000 non-null  float64
#  4   total_score              1000000 non-null  float64
#  5   grade                    1000000 non-null  str
#  6   grade_numeric            993796 non-null   float64
# dtypes: float64(5), int64(1), str(1)
# memory usage: 54.4 MB

# %%
plt.scatter(df['weekly_self_study_hours'], df['grade_numeric'])
plt.xlabel('weekly_self_study_hours')
plt.ylabel('grade_numeric')
# Out:
# Text(0, 0.5, 'grade_numeric')

# %%
numeric_df = df.select_dtypes(include='number')
numeric_df.corr()
# Out:
#                          student_id  weekly_self_study_hours  \
# student_id                 1.000000                -0.001607
# weekly_self_study_hours   -0.001607                 1.000000
# attendance_percentage     -0.000353                -0.001008
# class_participation        0.001277                 0.001244
# total_score               -0.000492                 0.812241
# grade_numeric             -0.000574                 0.738252
#
#                          attendance_percentage  class_participation  \
# student_id                           -0.000353             0.001277
# weekly_self_study_hours              -0.001008             0.001244
# attendance_percentage                 1.000000            -0.000043
# class_participation                  -0.000043             1.000000
# total_score                          -0.001014             0.000684
# grade_numeric                        -0.000396             0.000791
#
#                          total_score  grade_numeric
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df[['weekly_self_study_hours', 'attendance_percentage', 'class_participation']]
y = df['grade_numeric']

# %%
from sklearn.model_selection import train_test_split

# %%
# Drop rows with NaN values
df_clean = df.dropna(subset=['grade_numeric'])
X = df_clean[['weekly_self_study_hours', 'attendance_percentage', 'class_participation']]
y = df_clean['grade_numeric']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_train)

# %%
slope=model.coef_
slope
# Out:
# array([ 9.49765451e-02, -5.20962777e-06,  3.93235562e-05])

# %%
intercept=model.intercept_
intercept
# Out:
# np.float64(1.8839880616038074)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,root_mean_squared_error,r2_score

# %%
model.predict(X_test)
# Out:
# array([2.064311  , 3.43184158, 3.19455602, ..., 4.21062771, 4.41025166,
#        3.07088399], shape=(198760,))

# %%
score=r2_score(y_train,y_pred)
score
# Out:
# 0.5447270351226561

# %%
x= df.drop(columns='Performance Index')
y=df[;Performace I]
# Out:
#   Cell In[1], line 2
#     y=df[;Performace I]
#          ^
# SyntaxError: invalid syntax

# %%
num_cols=X.select_dtypes(include='number').columns
obj_cols=X.select_dtypes(include='object').columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 num_cols=X.select_dtypes(include='number').columns
#       2 obj_cols=X.select_dtypes(include='object').columns
#
# NameError: name 'X' is not defined
