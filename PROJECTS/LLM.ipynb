# %% [markdown]
# # LLMs are only for supervised learning

# %%
# pip install langchain_google_genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm_model = ChatGoogleGenerativeAI(
    model = 'gemini-3.5-flash',
    api_key = 'AIzaSyDZjtVW5K7xqtcpYywb8Lr7mrm009B_GwA'
)

# %%
response = llm_model.invoke("Explain Linear Regression in ML?")

# %%
print(response.content[0]['text'])
# Out:
# **Linear Regression** is one of the most fundamental, simple, and widely used algorithms in Machine Learning. It belongs to the **Supervised Learning** category and is used for **Regression tasks** (predicting continuous, numerical values).
#
# Here is a comprehensive breakdown of Linear Regression, how it works, and its key concepts.
#
# ---
#
# ### 1. The Core Idea
# The goal of Linear Regression is to find a linear relationship between one or more **independent variables (predictors/features)** and a **dependent variable (target/output)**.
#
# In simple terms, it tries to fit a **straight line** (or a hyperplane in higher dimensions) through the data points that best represents the trend.
#
# *   **Example:** Predicting a house's price (Target) based on its size in square feet (Feature).
#
# ---
#
# ### 2. The Mathematical Equation
#
# #### A. Simple Linear Regression (One Feature)
# When there is only one independent variable ($x$), the relationship is modeled using the equation of a straight line:
#
# $$y = \beta_0 + \beta_1x + \epsilon$$
#
# *   **$y$**: The predicted value (dependent variable).
# *   **$x$**: The input value (independent variable).
# *   **$\beta_1$ (Slope/Weight):** Represents the impact of $x$ on $y$. (e.g., how much does house price increase per square foot?).
# *   **$\beta_0$ (y-intercept/Bias):** The value of $y$ when $x = 0$.
# *   **$\epsilon$ (Error/Residual):** The difference between the actual value and the predicted value (noise).
#
# #### B. Multiple Linear Regression (Multiple Features)
# When there are multiple independent variables ($x_1, x_2, ..., x_n$), the equation becomes:
#
# $$y = \beta_0 + \beta_1x_1 + \beta_2x_2 + ... + \beta_nx_n + \epsilon$$
#
# *   *Example:* Predicting house price ($y$) based on size ($x_1$), number of bedrooms ($x_2$), and age of the house ($x_3$).
#
# ---
#
# ### 3. How Does the Algorithm Learn? (Finding the "Best Fit" Line)
#
# To find the "best" line, the algorithm must minimize the error between its predictions and the actual data points.
#
# #### Step 1: Define the Loss Function (Mean Squared Error)
# The most common way to measure error is **Mean Squared Error (MSE)**. It calculates the average of the squared differences between actual values ($y$) and predicted values ($\hat{y}$):
#
# $$MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2$$
#
# *We square the errors so that positive and negative errors don't cancel each other out, and to penalize larger errors more heavily.*
#
# #### Step 2: Optimization (Gradient Descent)
# To find the values of $\beta_0$ and $\beta_1$ that give the lowest MSE, ML uses an optimization algorithm called **Gradient Descent**.
# *   Imagine standing on top of a valley (high error) and wanting to reach the bottom (lowest error).
# *   Gradient Descent takes small steps downward by calculating the slope (gradient) of the error function until it reaches the lowest point (the minimum error).
#
# ---
#
# ### 4. Assumptions of Linear Regression
# For Linear Regression to perform well, the data should meet these key assumptions:
# 1.  **Linearity:** The relationship between the independent and dependent variables must be linear.
# 2.  **Independence:** The data points (observations) must be independent of each other.
# 3.  **Homoscedasticity:** The variance of residual errors should be constant across all levels of the independent variables.
# 4.  **Normal Distribution of Errors:** The residuals (errors) should follow a normal distribution.
# 5.  **No Multicollinearity:** (For Multiple Regression) The independent variables should not be highly correlated with each other.
#
# ---
#
# ### 5. How to Evaluate the Model?
# Once trained, how do we know if the model is good? We use these metrics:
#
# *   **$R^2$ Score (Coefficient of Determination):** Measures how much of the variation in $y$ is explained by $x$. It ranges from 0 to 1. An $R^2$ of 0.8 means 80% of the variance is explained by the model (closer to 1 is better).
# *   **Mean Absolute Error (MAE):** The average of the absolute differences between actual and predicted values. Easy to interpret.
# *   **Root Mean Squared Error (RMSE):** The square root of MSE. It is in the same units as the target variable $y$, making it highly readable.
#
# ---
#
# ### 6. Pros and Cons
#
# #### Pros:
# *   **Simple and Intuitive:** Easy to understand and explain to non-technical stakeholders.
# *   **Fast:** Extremely fast to train and make predictions.
# *   **Interpretable:** The coefficients ($\beta$) directly tell you the importance of each feature.
#
# #### Cons:
# *   **Assumes Linearity:** Real-world data is rarely perfectly linear, leading to **underfitting**.
# *   **Sensitive to Outliers:** A single extreme data point can heavily skew the "best fit" line.
# *   **Overfitting:** If you have too many features, the model might memorize the training data (can be fixed using regularization techniques like Ridge or Lasso regression).
#
# ---
#
# ### 7. Code Example (Python & Scikit-Learn)
#
# Here is how simple it is to implement in Python:
#
# ```python
# from sklearn.linear_model import LinearRegression
# import numpy as np
#
# # Sample Data: Size of house (sq ft) -> Price (in $1000s)
# X = np.array([[1000], [1500], [2000], [2500]]) # Features
# y = np.array([200, 300, 400, 500])             # Target
#
# # Initialize and train the model
# model = LinearRegression()
# model.fit(X, y)
#
# # Predict the price of a 1800 sq ft house
# predicted_price = model.predict([[1800]])
# print(f"Predicted Price: ${predicted_price[0]:.2f}k")
# # Output will be: Predicted Price: $360.00k
# ```
