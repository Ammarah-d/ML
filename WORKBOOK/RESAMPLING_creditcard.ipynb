# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# %%
#create account in huggingface
#pip install langchain
#pip install langchain_google_genai

# %%
# We can use Scaling technique

# %%
# download medical imbalnaced dataset use column tranformer and pipeline ,it should handle this using column tranformer and pipeline 
# dont create object
# if we have missing values use simpleimputer 
# use scaling and encoding if required
