# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# sentence based classfification - fake news, sentiment IMDB
#medical dataset imbalanced dataset - diabetes,brca,stoke prediction
#regression except house price - Automobile,fishers
#clustering - wholesale,mall

# %%
# SP(new) Target cols->final_exam_score & final grade  ==> select final_exm_score
# mixed cols-> 1st option-> tree based algo, start with DTC If underfit- select XGBC, RFC otherwise (DT will never check rel b/w independent and dependent cols)
# WHY NOT LOGR??? ->it uses regression formula internally
# 2nd option= GAUSSIANNB
# 3rd option-> Log R

# multiple dimensions->LOG R>Regularization>Lasso
# if !Target => use Clustering
# if !Target (requirement said use SL) => CREATE TARGET COLUMN
# DEEP LEARNINg =LSTM,CNN,GRU,RNN  learn architecture,flow 
# learn methods and plot from DA

# %%
#Text-to-speech and speech-to-text models
# speech-to-text fast whisper(openai) or whisper large v3 turbo
# TTS kokoro, sherpa onnx
#v4c.ai/careers
#opencode.ai for models 
# these models can be accessed using huggingface - kokoro tts model
